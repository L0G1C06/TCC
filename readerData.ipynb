# %%
import polars as pl

# df = pl.read_parquet(
#     "s3://storage-rumolog/data/portal_da_transparencia/parquet/modulo=bolsa-familia-saques/ano=2021/mes=10/202110_BolsaFamilia_Saques.parquet",
#     storage_options={
#         "aws_region": "sa-east-1"
#     }
# )
df = pl.read_parquet("/home/weber/projects/Facens/TCC/tmpo2g0e24p.parquet")

df
# Out:
# shape: (5_621, 24)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ Número do ┆ Objeto    ┆ Fundament ┆ Modalidad ┆ … ┆ Código UG ┆ Nome UG   ┆ Código    ┆ Modalida │
# │ Contrato  ┆ ---       ┆ o Legal   ┆ e Compra  ┆   ┆ Licitação ┆ Licitação ┆ Modalidad ┆ de       │
# │ ---       ┆ str       ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ e Compra  ┆ Compra   │
# │ str       ┆           ┆ str       ┆ str       ┆   ┆ str       ┆ str       ┆ Licit…    ┆ Licitaçã │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ ---       ┆ o        │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ str       ┆ ---      │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ str      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# ...
