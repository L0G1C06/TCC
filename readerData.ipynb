# %%
import polars as pl

df = pl.read_parquet(
    "s3://storage-rumolog/data/portal_da_transparencia/parquet/modulo=acordos-leniencia/ano=2026/mes=03/20260302_Acordos.parquet",
    storage_options={
        "aws_region": "sa-east-1"
    }
)

df.head()
# Out:
# shape: (5, 11)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ ID DO     ┆ CNPJ DO   ┆ RAZÃO     ┆ NOME      ┆ … ┆ DATA DA   ┆ NÚMERO DO ┆ TERMOS DO ┆ ÓRGÃO    │
# │ ACORDO    ┆ SANCIONAD ┆ SOCIAL   ┆ FANTASIA  ┆   ┆ INFORMAÇÃ ┆ PROCESSO  ┆ ACORDO    ┆ SANCIONA │
# │ ---       ┆ O         ┆ CADASTRO  ┆          ┆   ┆ O         ┆ ---       ┆ ---       ┆ DOR      │
# │ i64       ┆ ---       ┆ RECEIT…   ┆ CADASTRO  ┆   ┆ ---       ┆ str       ┆ str       ┆ ---      │
# │           ┆ str       ┆ ---       ┆ RECEI…    ┆   ┆ null      ┆           ┆           ┆ str      │
# │           ┆           ┆ str       ┆ ---       ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆           ┆ str       ┆   ┆           ┆           ┆           ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# ...
